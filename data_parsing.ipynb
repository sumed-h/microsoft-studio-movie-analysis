# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# not neccessary at the current time 
#akasdf = pd.read_csv('data/zippedData/imdb.title.akas.csv.gz')
#ratingsdf = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')
#movieinfodf = pd.read_csv('data/zippedData/rt.movie_info.tsv.gz', sep='\t')
#tmdbdf = pd.read_csv('data/zippedData/tmdb.movies.csv.gz', index_col=0)
#reviewsdf = pd.read_csv('data/zippedData/rt.reviews.tsv.gz', sep='\t', encoding = 'unicode_escape')
#I don't really know what this encoding parameter is doing but I got it to open the data!

# %%
grossdf = pd.read_csv('data/zippedData/bom.movie_gross.csv.gz')
namesdf = pd.read_csv('data/zippedData/imdb.name.basics.csv.gz')
titlesdf = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
crewdf = pd.read_csv('data/zippedData/imdb.title.crew.csv.gz')
principalsdf = pd.read_csv('data/zippedData/imdb.title.principals.csv.gz')
budgetdf = pd.read_csv('data/zippedData/tn.movie_budgets.csv.gz')

# %%
#grabbing the relevant columns from the titles dataframe that I want to merge into my budget dataframe
genres = titlesdf[['primary_title', 'genres']]

# %% [markdown]
# I've located the top net grossing films and now want to figure out why they are so successful

# %%
#highest grossing movies
#removed the commas and dollar signs from the data so that it could be converted
#reassigned the data to a float type instead of object so that it may be sorted properly
#assinged that now to an int so that it is easier to read
#since I'm on a PC for some reason I cannot just convert to int
#only selected the movies from the past 20 years
#established a column for net gross by subtracting the budget from the worldwide gross
#merged in my genres so that I may only select action movies
#selected the top 20 grossing action movies from the past 20 years
budgetdf.replace(',','', regex=True, inplace=True)
budgetdf.replace('\$','', regex=True, inplace=True)
budgetdf['production_budget'] = budgetdf['production_budget'].astype(float)
budgetdf['worldwide_gross'] = budgetdf['worldwide_gross'].astype(float)
budgetdf['domestic_gross'] = budgetdf['domestic_gross'].astype(float)
budgetdf['production_budget'] = budgetdf['production_budget'].astype(int)
budgetdf['worldwide_gross'] = budgetdf['worldwide_gross'].astype(int)
budgetdf['domestic_gross'] = budgetdf['domestic_gross'].astype(int)
budgetdf['release_date'] = pd.to_datetime(budgetdf['release_date'])
budgetdf = budgetdf[budgetdf['release_date'].dt.year >= 2001]
budgetdf['total_profit'] = budgetdf['worldwide_gross'] - budgetdf['production_budget']
budgetandgenres = budgetdf.merge(genres, left_on=['movie'], right_on=['primary_title'])
actiondf = budgetandgenres[budgetandgenres['genres'].str.contains('Action') == True]
highestactiondf = actiondf.sort_values(by='total_profit', ascending=False)
highest20df = highestactiondf.head(20)
highest20df
# Out:
#      id release_date                            movie  production_budget  \
# 4     7   2018-04-27           Avengers: Infinity War          300000000
# 24   34   2015-06-12                   Jurassic World          215000000
# 58   67   2015-04-03                        Furious 7          190000000
# 19   27   2012-05-04                     The Avengers          225000000
# 38   42   2018-02-16                    Black Panther          200000000
# 102  13   2018-06-22   Jurassic World: Fallen Kingdom          170000000
# 3     4   2015-05-01          Avengers: Age of Ultron          330600000
# 39   44   2018-06-15                    Incredibles 2          200000000
# 43   48   2013-05-03                       Iron Man 3          200000000
# 124  36   2018-12-21                          Aquaman          160000000
# 17   23   2017-04-14          The Fate of the Furious          250000000
# 83   96   2019-03-08                   Captain Marvel          175000000
# 55   64   2011-06-29   Transformers: Dark of the Moon          195000000
# 47   52   2012-11-08                          Skyfall          200000000
# 26   37   2014-06-27  Transformers: Age of Extinction          210000000
# 12   17   2016-05-06       Captain America: Civil War          250000000
# 385  38   2017-12-20   Jumanji: Welcome to the Jungle           90000000
# 40   45   2016-12-16     Rogue One: A Star Wars Story          200000000
# 7    11   2012-07-20            The Dark Knight Rises          275000000
# 616  56   2016-02-12                         Deadpool           58000000
#
#      domestic_gross  worldwide_gross  total_profit  \
# 4         678815482       2048134200    1748134200
# 24        652270625       1648854864    1433854864
# 58        353007020       1518722794    1328722794
# 19        623279547       1517935897    1292935897
# 38        700059566       1348258224    1148258224
# 102       417719760       1305772799    1135772799
# 3         459005868       1403013963    1072413963
# 39        608581744       1242520711    1042520711
# 43        408992272       1215392272    1015392272
# 124       335061807       1146894640     986894640
# 17        225764765       1234846267     984846267
# 83        426525952       1123061550     948061550
# 55        352390543       1123790543     928790543
# 47        304360277       1110526981     910526981
# 26        245439076       1104039076     894039076
# 12        408084349       1140069413     890069413
# 385       404508916        964496193     874496193
# 40        532177324       1049102856     849102856
# 7         448139099       1084439099     809439099
# 616       363070709        801025593     743025593
#
#                        primary_title                      genres
# 4             Avengers: Infinity War     Action,Adventure,Sci-Fi
# 24                    Jurassic World     Action,Adventure,Sci-Fi
# 58                         Furious 7       Action,Crime,Thriller
# 19                      The Avengers     Action,Adventure,Sci-Fi
# 38                     Black Panther     Action,Adventure,Sci-Fi
# 102   Jurassic World: Fallen Kingdom     Action,Adventure,Sci-Fi
# 3            Avengers: Age of Ultron     Action,Adventure,Sci-Fi
# 39                     Incredibles 2  Action,Adventure,Animation
# 43                        Iron Man 3     Action,Adventure,Sci-Fi
# 124                          Aquaman    Action,Adventure,Fantasy
# 17           The Fate of the Furious       Action,Crime,Thriller
# 83                    Captain Marvel     Action,Adventure,Sci-Fi
# 55    Transformers: Dark of the Moon     Action,Adventure,Sci-Fi
# 47                           Skyfall   Action,Adventure,Thriller
# 26   Transformers: Age of Extinction     Action,Adventure,Sci-Fi
# 12        Captain America: Civil War     Action,Adventure,Sci-Fi
# 385   Jumanji: Welcome to the Jungle     Action,Adventure,Comedy
# 40      Rogue One: A Star Wars Story     Action,Adventure,Sci-Fi
# 7              The Dark Knight Rises             Action,Thriller
# 616                         Deadpool     Action,Adventure,Comedy

# %%
from matplotlib.ticker import FuncFormatter
def millions(y, pos):
    return '$%1.0fM' % (y*1e-6)

stevenmoviefig, ax = plt.subplots(figsize=(15,8))
sns.barplot(y = highest20df['movie'], x = highest20df['total_profit'], color='#ffbb00')
ax.set_title('Highest Profiting Action Movies\n Over The Past Two Decades', fontsize= 16, weight=900)
ax.set_xlabel('Profit', fontsize= 16)
ax.set_ylabel('Movie', fontsize= 16)
formatter = FuncFormatter(millions)
ax.xaxis.set_major_formatter(formatter)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);
#plt.savefig('stevenmoviefig.jpg', dpi=300, bbox_inches='tight');

# %%
namesdf
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606643                                      NaN
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606646                                      NaN
# 606647                                tt8743182
#
# [606648 rows x 6 columns]

# %%
#grabbing the columns that I need
names = namesdf[['nconst','primary_name']]

# %%
#checking for null values
names.isnull().sum()
# Out:
# nconst          0
# primary_name    0
# dtype: int64

# %%
names
# Out:
#            nconst         primary_name
# 0       nm0061671    Mary Ellen Bauder
# 1       nm0061865         Joseph Bauer
# 2       nm0062070           Bruce Baum
# 3       nm0062195         Axel Baumann
# 4       nm0062798          Pete Baxter
# ...           ...                  ...
# 606643  nm9990381         Susan Grobes
# 606644  nm9990690          Joo Yeon So
# 606645  nm9991320       Madeline Smith
# 606646  nm9991786  Michelle Modigliani
# 606647  nm9993380       Pegasus Envoyé
#
# [606648 rows x 2 columns]

# %%
#I do the same for the rest of the databases I wish to merge
titlesdf.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
movietitles = titlesdf[['tconst','primary_title']]

# %%
movietitles.isnull().sum()
# Out:
# tconst           0
# primary_title    0
# dtype: int64

# %%
movietitles
# Out:
#            tconst                                primary_title
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
# [146144 rows x 2 columns]

# %%
principalsdf.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
crew = principalsdf[['tconst','nconst','category']]

# %%
crew.isnull().sum()
# Out:
# tconst      0
# nconst      0
# category    0
# dtype: int64

# %%
crew
# Out:
#             tconst      nconst  category
# 0        tt0111414   nm0246005     actor
# 1        tt0111414   nm0398271  director
# 2        tt0111414   nm3739909  producer
# 3        tt0323808   nm0059247    editor
# 4        tt0323808   nm3579312   actress
# ...            ...         ...       ...
# 1028181  tt9692684   nm0186469     actor
# 1028182  tt9692684   nm4929530      self
# 1028183  tt9692684  nm10441594  director
# 1028184  tt9692684   nm6009913    writer
# 1028185  tt9692684  nm10441595  producer
#
# [1028186 rows x 3 columns]

# %%
# Adding the names dataframe to principals
crewnames = names.merge(crew, on=['nconst'])
# Adding the titles 
namesandtitles = crewnames.merge(movietitles, on=['tconst'])
# Adding all that to the budget datafram
grosscrew = namesandtitles.merge(highestactiondf, left_on=['primary_title'], right_on=['movie'])

# %%
#Here it is!
grosscrew
# Out:
#           nconst     primary_name     tconst  category primary_title_x  id  \
# 0      nm0093589       Matt Bomer  tt3799694     actor   The Nice Guys  56
# 1      nm0000948      Shane Black  tt3799694  director   The Nice Guys  56
# 2      nm0331516     Ryan Gosling  tt3799694     actor   The Nice Guys  56
# 3      nm0000128    Russell Crowe  tt3799694     actor   The Nice Guys  56
# 4      nm0005428      Joel Silver  tt3799694  producer   The Nice Guys  56
# ...          ...              ...        ...       ...             ...  ..
# 11207  nm6825014  Gabriel Michael  tt5521836     actor      Panic Room  17
# 11208  nm7973173        Ben Yonko  tt5521836     actor      Panic Room  17
# 11209  nm6825011     G.M. Whiting  tt5521836  director      Panic Room  17
# 11210  nm7572519       Emma Meyer  tt5521836     actor      Panic Room  17
# 11211  nm6825012     Brock Brazda  tt5521836     actor      Panic Room  17
#
#       release_date          movie  production_budget  domestic_gross  \
# 0       2016-05-20  The Nice Guys           50000000        36261763
# 1       2016-05-20  The Nice Guys           50000000        36261763
# 2       2016-05-20  The Nice Guys           50000000        36261763
# 3       2016-05-20  The Nice Guys           50000000        36261763
# 4       2016-05-20  The Nice Guys           50000000        36261763
# ...            ...            ...                ...             ...
# 11207   2002-03-29     Panic Room           48000000        95308367
# 11208   2002-03-29     Panic Room           48000000        95308367
# 11209   2002-03-29     Panic Room           48000000        95308367
# 11210   2002-03-29     Panic Room           48000000        95308367
# 11211   2002-03-29     Panic Room           48000000        95308367
#
#        worldwide_gross  total_profit primary_title_y                genres
# 0             59596747       9596747   The Nice Guys   Action,Comedy,Crime
# 1             59596747       9596747   The Nice Guys   Action,Comedy,Crime
# 2             59596747       9596747   The Nice Guys   Action,Comedy,Crime
# 3             59596747       9596747   The Nice Guys   Action,Comedy,Crime
# 4             59596747       9596747   The Nice Guys   Action,Comedy,Crime
# ...                ...           ...             ...                   ...
# 11207        196308367     148308367      Panic Room  Action,Drama,Mystery
# 11208        196308367     148308367      Panic Room  Action,Drama,Mystery
# 11209        196308367     148308367      Panic Room  Action,Drama,Mystery
# 11210        196308367     148308367      Panic Room  Action,Drama,Mystery
# 11211        196308367     148308367      Panic Room  Action,Drama,Mystery
#
# [11212 rows x 14 columns]

# %%
#Copying the dataframe into a sorted by the highest worldwide gross
highestgrosscrew = grosscrew.sort_values(by='total_profit', ascending=False)

# %%
highestgrosscrew
# Out:
#          nconst        primary_name     tconst  category  \
# 3735  nm1165110     Chris Hemsworth  tt4154756     actor
# 3732  nm0751648           Joe Russo  tt4154756  director
# 3734  nm0749263        Mark Ruffalo  tt4154756     actor
# 3736  nm0751577       Anthony Russo  tt4154756  director
# 3737  nm0262635         Chris Evans  tt4154756     actor
# ...         ...                 ...        ...       ...
# 9857  nm0126208          John Byrne  tt6565702    writer
# 9858  nm1055413  Michael Fassbender  tt6565702     actor
# 9859  nm2225369   Jennifer Lawrence  tt6565702   actress
# 9860  nm1334526       Simon Kinberg  tt6565702  director
# 9853  nm0564215        James McAvoy  tt6565702     actor
#
#              primary_title_x  id release_date                   movie  \
# 3735  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# 3732  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# 3734  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# 3736  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# 3737  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# ...                      ...  ..          ...                     ...
# 9857            Dark Phoenix   3   2019-06-07            Dark Phoenix
# 9858            Dark Phoenix   3   2019-06-07            Dark Phoenix
# 9859            Dark Phoenix   3   2019-06-07            Dark Phoenix
# 9860            Dark Phoenix   3   2019-06-07            Dark Phoenix
# 9853            Dark Phoenix   3   2019-06-07            Dark Phoenix
#
#       production_budget  domestic_gross  worldwide_gross  total_profit  \
# 3735          300000000       678815482       2048134200    1748134200
# 3732          300000000       678815482       2048134200    1748134200
# 3734          300000000       678815482       2048134200    1748134200
# 3736          300000000       678815482       2048134200    1748134200
# 3737          300000000       678815482       2048134200    1748134200
# ...                 ...             ...              ...           ...
# 9857          350000000        42762350        149762350    -200237650
# 9858          350000000        42762350        149762350    -200237650
# 9859          350000000        42762350        149762350    -200237650
# 9860          350000000        42762350        149762350    -200237650
# 9853          350000000        42762350        149762350    -200237650
#
#              primary_title_y                   genres
# 3735  Avengers: Infinity War  Action,Adventure,Sci-Fi
# 3732  Avengers: Infinity War  Action,Adventure,Sci-Fi
# 3734  Avengers: Infinity War  Action,Adventure,Sci-Fi
# 3736  Avengers: Infinity War  Action,Adventure,Sci-Fi
# 3737  Avengers: Infinity War  Action,Adventure,Sci-Fi
# ...                      ...                      ...
# 9857            Dark Phoenix  Action,Adventure,Sci-Fi
# 9858            Dark Phoenix  Action,Adventure,Sci-Fi
# 9859            Dark Phoenix  Action,Adventure,Sci-Fi
# 9860            Dark Phoenix  Action,Adventure,Sci-Fi
# 9853            Dark Phoenix  Action,Adventure,Sci-Fi
#
# [11212 rows x 14 columns]

# %%
directors = highestgrosscrew.loc[highestgrosscrew['category'] == 'director']

# %%
directors.head()
# Out:
#          nconst     primary_name     tconst  category         primary_title_x  \
# 3732  nm0751648        Joe Russo  tt4154756  director  Avengers: Infinity War
# 3736  nm0751577    Anthony Russo  tt4154756  director  Avengers: Infinity War
# 2436  nm1119880  Colin Trevorrow  tt0369610  director          Jurassic World
# 3623  nm1490123        James Wan  tt2820852  director               Furious 7
# 5721  nm0923736      Joss Whedon  tt0848228  director            The Avengers
#
#       id release_date                   movie  production_budget  \
# 3732   7   2018-04-27  Avengers: Infinity War          300000000
# 3736   7   2018-04-27  Avengers: Infinity War          300000000
# 2436  34   2015-06-12          Jurassic World          215000000
# 3623  67   2015-04-03               Furious 7          190000000
# 5721  27   2012-05-04            The Avengers          225000000
#
#       domestic_gross  worldwide_gross  total_profit         primary_title_y  \
# 3732       678815482       2048134200    1748134200  Avengers: Infinity War
# 3736       678815482       2048134200    1748134200  Avengers: Infinity War
# 2436       652270625       1648854864    1433854864          Jurassic World
# 3623       353007020       1518722794    1328722794               Furious 7
# 5721       623279547       1517935897    1292935897            The Avengers
#
#                        genres
# 3732  Action,Adventure,Sci-Fi
# 3736  Action,Adventure,Sci-Fi
# 2436  Action,Adventure,Sci-Fi
# 3623    Action,Crime,Thriller
# 5721  Action,Adventure,Sci-Fi

# %%
#I want to treat the Russo Brothers as one since their data is the same and they work as a pair
#To do so I rename them as The Russo Brothers in my dataframe and drop the name and title constant columns so that
#I can also drop the duplicate values
directors.replace('Joe Russo','The Russo Brothers', regex=True, inplace=True)
directors.replace('Anthony Russo','The Russo Brothers', regex=True, inplace=True)
directors = directors.drop(['nconst', 'tconst'], axis=1)
directors = directors.drop_duplicates()
# Out:
# C:\Users\steve\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
directors.head()
# Out:
#             primary_name  category         primary_title_x  id release_date  \
# 3732  The Russo Brothers  director  Avengers: Infinity War   7   2018-04-27
# 2436     Colin Trevorrow  director          Jurassic World  34   2015-06-12
# 3623           James Wan  director               Furious 7  67   2015-04-03
# 5721         Joss Whedon  director            The Avengers  27   2012-05-04
# 9820        Ryan Coogler  director           Black Panther  42   2018-02-16
#
#                        movie  production_budget  domestic_gross  \
# 3732  Avengers: Infinity War          300000000       678815482
# 2436          Jurassic World          215000000       652270625
# 3623               Furious 7          190000000       353007020
# 5721            The Avengers          225000000       623279547
# 9820           Black Panther          200000000       700059566
#
#       worldwide_gross  total_profit         primary_title_y  \
# 3732       2048134200    1748134200  Avengers: Infinity War
# 2436       1648854864    1433854864          Jurassic World
# 3623       1518722794    1328722794               Furious 7
# 5721       1517935897    1292935897            The Avengers
# 9820       1348258224    1148258224           Black Panther
#
#                        genres
# 3732  Action,Adventure,Sci-Fi
# 2436  Action,Adventure,Sci-Fi
# 3623    Action,Crime,Thriller
# 5721  Action,Adventure,Sci-Fi
# 9820  Action,Adventure,Sci-Fi

# %%
directorgb = directors.groupby(['primary_name']).sum().sort_values(['total_profit'], ascending=False)

# %%
directorgb.head(10)
# Out:
#                      id  production_budget  domestic_gross  worldwide_gross  \
# primary_name
# The Russo Brothers   40        720000000.0    1.346647e+09     3.902606e+09
# Joss Whedon          31        555600000.0    1.082285e+09     2.920950e+09
# James Wan           103        350000000.0    6.880688e+08     2.665617e+09
# Michael Bay         167        648000000.0    7.778736e+08     2.911998e+09
# Francis Lawrence    191        484000000.0    1.090402e+09     2.426382e+09
# Christopher Nolan   118        585000000.0    9.307836e+08     2.419801e+09
# Sam Mendes           62        500000000.0    5.044345e+08     1.990148e+09
# Zack Snyder         208        950000000.0    9.424978e+08     2.420920e+09
# Colin Trevorrow      34        215000000.0    6.522706e+08     1.648855e+09
# Gareth Edwards       86        360000000.0    7.328534e+08     1.578179e+09
#
#                     total_profit
# primary_name
# The Russo Brothers  3.182606e+09
# Joss Whedon         2.365350e+09
# James Wan           2.315617e+09
# Michael Bay         2.263998e+09
# Francis Lawrence    1.942382e+09
# Christopher Nolan   1.834801e+09
# Sam Mendes          1.490148e+09
# Zack Snyder         1.470920e+09
# Colin Trevorrow     1.433855e+09
# Gareth Edwards      1.218179e+09

# %%
top10directors = directorgb.head(10)

# %%
stevendirectorfig, ax = plt.subplots(figsize=(15,8))
sns.barplot(y = top10directors.index, x = top10directors['total_profit'], color='#7cbb00')
ax.set_title('Highest Profiting Action Movie Directors\n Over The Past Two Decades', fontsize= 14, weight=900)
ax.set_xlabel('Total Profit', fontsize= 14)
ax.set_ylabel('Director', fontsize= 14)
formatter = FuncFormatter(millions)
ax.xaxis.set_major_formatter(formatter)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);
#plt.savefig('stevendirectorfig.jpg', dpi=300, bbox_inches='tight');

# %%
# I repeat the process for Actors and Actresses

# %%
actors = highestgrosscrew.loc[highestgrosscrew['category'] == 'actor']

# %%
actors.head()
# Out:
#          nconst       primary_name     tconst category  \
# 3735  nm1165110    Chris Hemsworth  tt4154756    actor
# 3734  nm0749263       Mark Ruffalo  tt4154756    actor
# 3737  nm0262635        Chris Evans  tt4154756    actor
# 3739  nm0000375  Robert Downey Jr.  tt4154756    actor
# 2433  nm0695435        Chris Pratt  tt0369610    actor
#
#              primary_title_x  id release_date                   movie  \
# 3735  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# 3734  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# 3737  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# 3739  Avengers: Infinity War   7   2018-04-27  Avengers: Infinity War
# 2433          Jurassic World  34   2015-06-12          Jurassic World
#
#       production_budget  domestic_gross  worldwide_gross  total_profit  \
# 3735          300000000       678815482       2048134200    1748134200
# 3734          300000000       678815482       2048134200    1748134200
# 3737          300000000       678815482       2048134200    1748134200
# 3739          300000000       678815482       2048134200    1748134200
# 2433          215000000       652270625       1648854864    1433854864
#
#              primary_title_y                   genres
# 3735  Avengers: Infinity War  Action,Adventure,Sci-Fi
# 3734  Avengers: Infinity War  Action,Adventure,Sci-Fi
# 3737  Avengers: Infinity War  Action,Adventure,Sci-Fi
# 3739  Avengers: Infinity War  Action,Adventure,Sci-Fi
# 2433          Jurassic World  Action,Adventure,Sci-Fi

# %%
actorgb = actors.groupby(['primary_name']).sum().sort_values(['total_profit'], ascending=False)

# %%
top10actors = actorgb.head(10)

# %%
stevenactorfig, ax = plt.subplots(figsize=(15,8))
sns.barplot(y = top10actors.index, x = top10actors['total_profit'], color='#00a1f1')

ax.set_title('Highest Profiting Action Movie Actors\n Over The Past Two Decades',fontsize= 14,weight=900)
ax.set_xlabel('Total Profit',fontsize= 14)
ax.set_ylabel('Actor',fontsize= 14)
formatter = FuncFormatter(millions)
ax.xaxis.set_major_formatter(formatter)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);
#plt.savefig('stevenactorfig.jpg', dpi=300, bbox_inches='tight');

# %%
actresses = highestgrosscrew.loc[highestgrosscrew['category'] == 'actress']

# %%
actresses.head(10)
# Out:
#          nconst         primary_name     tconst category  \
# 2434  nm0397171  Bryce Dallas Howard  tt0369610  actress
# 2432  nm0339460           Judy Greer  tt0369610  actress
# 5714  nm0424060   Scarlett Johansson  tt0848228  actress
# 9819  nm1775091         Danai Gurira  tt1825683  actress
# 9817  nm2143282       Lupita Nyong'o  tt1825683  actress
# 2443  nm0397171  Bryce Dallas Howard  tt4881806  actress
# 3814  nm1102970         Sarah Vowell  tt3606756  actress
# 3811  nm0000456         Holly Hunter  tt3606756  actress
# 9334  nm0000569      Gwyneth Paltrow  tt1300854  actress
# 7655  nm1720028          Amber Heard  tt1477834  actress
#
#                      primary_title_x  id release_date  \
# 2434                  Jurassic World  34   2015-06-12
# 2432                  Jurassic World  34   2015-06-12
# 5714                    The Avengers  27   2012-05-04
# 9819                   Black Panther  42   2018-02-16
# 9817                   Black Panther  42   2018-02-16
# 2443  Jurassic World: Fallen Kingdom  13   2018-06-22
# 3814                   Incredibles 2  44   2018-06-15
# 3811                   Incredibles 2  44   2018-06-15
# 9334                      Iron Man 3  48   2013-05-03
# 7655                         Aquaman  36   2018-12-21
#
#                                movie  production_budget  domestic_gross  \
# 2434                  Jurassic World          215000000       652270625
# 2432                  Jurassic World          215000000       652270625
# 5714                    The Avengers          225000000       623279547
# 9819                   Black Panther          200000000       700059566
# 9817                   Black Panther          200000000       700059566
# 2443  Jurassic World: Fallen Kingdom          170000000       417719760
# 3814                   Incredibles 2          200000000       608581744
# 3811                   Incredibles 2          200000000       608581744
# 9334                      Iron Man 3          200000000       408992272
# 7655                         Aquaman          160000000       335061807
#
#       worldwide_gross  total_profit                 primary_title_y  \
# 2434       1648854864    1433854864                  Jurassic World
# 2432       1648854864    1433854864                  Jurassic World
# 5714       1517935897    1292935897                    The Avengers
# 9819       1348258224    1148258224                   Black Panther
# 9817       1348258224    1148258224                   Black Panther
# 2443       1305772799    1135772799  Jurassic World: Fallen Kingdom
# 3814       1242520711    1042520711                   Incredibles 2
# 3811       1242520711    1042520711                   Incredibles 2
# 9334       1215392272    1015392272                      Iron Man 3
# 7655       1146894640     986894640                         Aquaman
#
#                           genres
# 2434     Action,Adventure,Sci-Fi
# 2432     Action,Adventure,Sci-Fi
# 5714     Action,Adventure,Sci-Fi
# 9819     Action,Adventure,Sci-Fi
# 9817     Action,Adventure,Sci-Fi
# 2443     Action,Adventure,Sci-Fi
# 3814  Action,Adventure,Animation
# 3811  Action,Adventure,Animation
# 9334     Action,Adventure,Sci-Fi
# 7655    Action,Adventure,Fantasy

# %%
actressesgb = actresses.groupby(['primary_name']).sum().sort_values(['total_profit'], ascending=False)

# %%
top10actresses = actressesgb.head(10)

# %%
top10actresses
# Out:
#                       id  production_budget  domestic_gross  worldwide_gross  \
# primary_name
# Scarlett Johansson   183       7.950000e+08    1.458248e+09     3.997826e+09
# Jennifer Lawrence    367       1.252000e+09    1.843026e+09     4.152013e+09
# Bryce Dallas Howard   47       3.850000e+08    1.069990e+09     2.954628e+09
# Cate Blanchett       443       1.720000e+09    1.238359e+09     3.674994e+09
# Angelina Jolie       304       7.000000e+08    7.361275e+08     2.510355e+09
# Emma Stone           117       6.150000e+08    6.980539e+08     2.144056e+09
# Gwyneth Paltrow      182       4.900000e+08    8.047798e+08     2.004496e+09
# Brie Larson          326       4.370000e+08    7.685067e+08     1.929458e+09
# Judy Greer            34       2.150000e+08    6.522706e+08     1.648855e+09
# Morena Baccarin       71       1.680000e+08    6.876624e+08     1.587706e+09
#
#                      total_profit
# primary_name
# Scarlett Johansson   3.202826e+09
# Jennifer Lawrence    2.900013e+09
# Bryce Dallas Howard  2.569628e+09
# Cate Blanchett       1.954994e+09
# Angelina Jolie       1.810355e+09
# Emma Stone           1.529056e+09
# Gwyneth Paltrow      1.514496e+09
# Brie Larson          1.492458e+09
# Judy Greer           1.433855e+09
# Morena Baccarin      1.419706e+09

# %%
stevenactressfig, ax = plt.subplots(figsize=(15,8))
sns.barplot(y = top10actresses.index, x = top10actresses['total_profit'], color='#f65314')
ax.set_title('Highest Profiting Action Movie Actresses\n Over The Past Two Decades',fontsize= 14,weight=900)
ax.set_xlabel('Total Profit',fontsize= 14)
ax.set_ylabel('Actresses',fontsize= 14)
formatter = FuncFormatter(millions)
ax.xaxis.set_major_formatter(formatter)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);
#plt.savefig('stevenactressfig.jpg', dpi=300, bbox_inches='tight');
